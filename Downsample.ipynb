# %%
# Libraries
from google.cloud import bigquery
import pandas as pd
import numpy as np
import matplotlib as plt
# client location
client = bigquery.Client(location = "europe-north1")
print("Client creating using default project: {}".format(client.project))
# Out:
# Client creating using default project: gentle-pier-291608

# %% [markdown]
# N = 1

# %%
# determine number of failures
query = """
    SELECT COUNT(failure)
    FROM df.m1days
    WHERE failure = 1
    """
query_job = client.query(query, location= "europe-north1")  # API request - starts the query
n_failure = query_job.to_dataframe()
print("N_failures:", n_failure.values[0][0])
# Out:
# N_failure [[3868]]

# %%
# determine number of healthy
query = """
    SELECT COUNT(failure)
    FROM df.m1days
    WHERE failure = 0
    """
query_job = client.query(query, location= "europe-north1")  # API request - starts the query
n_healthy = query_job.to_dataframe()
print("N_healthy:", n_healthy.values[0][0])
# Out:
# N_healthy: 55534433

# %%
# goal: 
to_drop = n_healthy.values[0][0] - n_failure.values[0][0]
to_drop
# Out:
# 55530565

# %%
# import dataset
query = """
    SELECT * EXCEPT(random)
    FROM df.M1N1D
    """
query_job = client.query(query, location= "europe-north1")  # API request - starts the query
M1N1D = query_job.to_dataframe()
M1N1D.head()
# Out:
#    failure  smart_12_normalized  smart_12_raw  smart_183_normalized  \
# 0        0                  100             4                   100
# 1        0                  100             9                   100
# 2        0                  100             6                    99
# 3        0                  100             5                   100
# 4        0                  100             5                   100
#
#    smart_183_raw  smart_184_normalized  smart_184_raw  smart_187_normalized  \
# 0              0                   100              0                   100
# 1              0                   100              0                   100
# 2              1                   100              0                   100
# 3              0                   100              0                   100
# 4              0                   100              0                   100
#
#    smart_187_raw  smart_188_normalized  ...  smart_242_raw  \
# ...

# %%
M1N1D.groupby(["failure"]).agg(["count"])
# Out:
#         smart_12_normalized smart_12_raw smart_183_normalized smart_183_raw  \
#                       count        count                count         count
# failure
# 0                      3868         3868                 3868          3868
# 1                      3868         3868                 3868          3868
#
#         smart_184_normalized smart_184_raw smart_187_normalized smart_187_raw  \
#                        count         count                count         count
# failure
# 0                       3868          3868                 3868          3868
# 1                       3868          3868                 3868          3868
#
#         smart_188_normalized smart_188_raw  ... smart_242_raw  \
#                        count         count  ...         count
# failure                                     ...
# 0                       3868          3868  ...          3868
# 1                       3868          3868  ...          3868
#
# ...

# %% [markdown]
# N = 5

# %%
# determine number of failures
query = """
    SELECT COUNT(failureN5)
    FROM df.m1N5
    WHERE failureN5 = 1
    """
query_job = client.query(query, location= "europe-north1")  # API request - starts the query
n_failure = query_job.to_dataframe()
print("N_failures:", n_failure.values[0][0])
# Out:
# N_failures: 23032

# %%
# import dataset
query = """
    SELECT failure, * EXCEPT(failure, random)
    FROM df.M1N5D
    """
query_job = client.query(query, location= "europe-north1")  # API request - starts the query
M1N5D = query_job.to_dataframe()
M1N5D.head()
# Out:
#    failure  smart_12_normalized  smart_12_raw  smart_183_normalized  \
# 0        1                  100             0                   100
# 1        1                  100             0                   100
# 2        1                  100             0                   100
# 3        1                  100             0                   100
# 4        1                  100             0                   100
#
#    smart_183_raw  smart_184_normalized  smart_184_raw  smart_187_normalized  \
# 0              0                   100              0                   100
# 1              0                   100              0                   100
# 2              0                   100              0                   100
# 3              0                   100              0                   100
# 4              0                    99              1                   100
#
#    smart_187_raw  smart_188_normalized  ...  smart_242_raw  \
# ...

# %%
M1N5D.groupby(["failure"]).agg(["count"])
# Out:
#         smart_12_normalized smart_12_raw smart_183_normalized smart_183_raw  \
#                       count        count                count         count
# failure
# 0                     23032        23032                23032         23032
# 1                     23032        23032                23032         23032
#
#         smart_184_normalized smart_184_raw smart_187_normalized smart_187_raw  \
#                        count         count                count         count
# failure
# 0                      23032         23032                23032         23032
# 1                      23032         23032                23032         23032
#
#         smart_188_normalized smart_188_raw  ... smart_242_raw  \
#                        count         count  ...         count
# failure                                     ...
# 0                      23032         23032  ...         23032
# 1                      23032         23032  ...         23032
#
# ...

# %% [markdown]
# N = 10

# %%
# determine number of failures
query = """
    SELECT COUNT(failureN5)
    FROM df.m1N10
    WHERE failureN5 = 1
    """
query_job = client.query(query, location= "europe-north1")  # API request - starts the query
n_failure = query_job.to_dataframe()
print("N_failures:", n_failure.values[0][0])
# Out:
# N_failures: 42037

# %%
# import dataset
query = """
    SELECT failure, * EXCEPT(failure, random)
    FROM df.M1N10D
    """
query_job = client.query(query, location= "europe-north1")  # API request - starts the query
M1N10D = query_job.to_dataframe()
M1N10D.head()
# Out:
#    failure  smart_12_normalized  smart_12_raw  smart_183_normalized  \
# 0        0                  100             8                   100
# 1        0                  100            14                   100
# 2        0                  100             4                   100
# 3        0                  100             1                   100
# 4        0                  100             7                   100
#
#    smart_183_raw  smart_184_normalized  smart_184_raw  smart_187_normalized  \
# 0              0                   100              0                   100
# 1              0                   100              0                   100
# 2              0                   100              0                   100
# 3              0                   100              0                   100
# 4              0                   100              0                   100
#
#    smart_187_raw  smart_188_normalized  ...  smart_242_raw  \
# ...

# %%
M1N10D.groupby(["failure"]).agg(["count"])
# Out:
#         smart_12_normalized smart_12_raw smart_183_normalized smart_183_raw  \
#                       count        count                count         count
# failure
# 0                     42037        42037                42037         42037
# 1                     42037        42037                42037         42037
#
#         smart_184_normalized smart_184_raw smart_187_normalized smart_187_raw  \
#                        count         count                count         count
# failure
# 0                      42037         42037                42037         42037
# 1                      42037         42037                42037         42037
#
#         smart_188_normalized smart_188_raw  ... smart_242_raw  \
#                        count         count  ...         count
# failure                                     ...
# 0                      42037         42037  ...         42037
# 1                      42037         42037  ...         42037
#
# ...

# %% [markdown]
# N = 15

# %%
# determine number of failures
query = """
    SELECT COUNT(failureN5)
    FROM df.m1N15
    WHERE failureN5 = 1
    """
query_job = client.query(query, location= "europe-north1")  # API request - starts the query
n_failure = query_job.to_dataframe()
print("N_failures:", n_failure.values[0][0])
# Out:
# N_failures: 60989

# %%
# select healthy instances at random
query = """
    SELECT *  
    FROM (SELECT rand() as random, failureN5 as failure, * EXCEPT (failureN5, date, serial_number, model, capacity_bytes)  
         FROM df.m1N15 
         WHERE failureN5 = 0
         ORDER BY random)
    LIMIT 60989
    """

# %%
# import dataset
query = """
    SELECT * EXCEPT(random)
    FROM df.M1N15D
    """
query_job = client.query(query, location= "europe-north1")  # API request - starts the query
M1N15D = query_job.to_dataframe()
M1N15D.head()
# Out:
#    failure  smart_12_normalized  smart_12_raw  smart_183_normalized  \
# 0        1                  100             0                   100
# 1        1                  100             0                   100
# 2        1                  100             0                   100
# 3        1                  100             0                   100
# 4        1                  100             0                   100
#
#    smart_183_raw  smart_184_normalized  smart_184_raw  smart_187_normalized  \
# 0              0                   100              0                   100
# 1              0                   100              0                   100
# 2              0                   100              0                   100
# 3              0                   100              0                   100
# 4              0                   100              0                   100
#
#    smart_187_raw  smart_188_normalized  ...  smart_242_raw  \
# ...

# %%
M1N10D.groupby(["failure"]).agg(["count"])
# Out:
#         smart_12_normalized smart_12_raw smart_183_normalized smart_183_raw  \
#                       count        count                count         count
# failure
# 0                     42037        42037                42037         42037
# 1                     42037        42037                42037         42037
#
#         smart_184_normalized smart_184_raw smart_187_normalized smart_187_raw  \
#                        count         count                count         count
# failure
# 0                      42037         42037                42037         42037
# 1                      42037         42037                42037         42037
#
#         smart_188_normalized smart_188_raw  ... smart_242_raw  \
#                        count         count  ...         count
# failure                                     ...
# 0                      42037         42037  ...         42037
# 1                      42037         42037  ...         42037
#
# ...

# %%
42037/55538301
# Out:
# 0.0007569010798511823
